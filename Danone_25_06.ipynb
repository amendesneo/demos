# %%
import ast
import time
import spacy
import warnings
import operator
import numpy as np
import pandas as pd
import logging as log
from tqdm import tqdm
from collections import Counter
warnings.filterwarnings("ignore")

class Matcher():
    def __init__(self):
        spacy.prefer_gpu() # or spacy.require_gpu()
        #self.nlp_en = spacy.load("en_core_web_lg")
        self.nlp = spacy.load("fr_core_news_md")
        
    def get_top_similarities(self, word, word_list, n, nlp):
        similarities = {}

        doc1 = nlp(str(word))

        for item in tqdm(word_list):
                doc2 = nlp(item)
                if item != word:
                    similarities[item] = doc1.similarity(doc2)

        return sorted(similarities.items(),key=operator.itemgetter(1),reverse=True)[:n]
    
    def get_top_similarities_parsed(self, word, word_list, n):
        similarities = {}

        doc1 = self.nlp_en(self.parse_sentence(word))

        for item in tqdm(word_list):
                doc2 = self.nlp_en(self.parse_sentence(item))
                if item != word:
                    similarities[item] = doc1.similarity(doc2)
                    
        return sorted(similarities.items(),key=operator.itemgetter(1),reverse=True)[:n]
    
    def get_top_similarities_en(self, word, word_list, n):
        return self.get_top_similarities(word, word_list, n, self.nlp)
    
    def parse_sentence(self, sentence):
        doc = self.nlp_en(sentence)

        words = [token.text for token in doc if token.is_stop != True and token.is_punct != True and token.pos_ != 'VERB'  and token.pos_ != 'ADJ']
        return ' '.join(words)
    
    #def get_top_similarities_fr(self, word, word_list, n):
    #    return self.get_top_similarities(word, word_list, n, self.nlp_en)

if __name__ == '__main__':
    matcher = Matcher()

# %%
import requests
import json
class Translator():  
   
    def get_translation(self,query,language="en"):
        url = "https://translation.googleapis.com/language/translate/v2?"
        key = "AIzaSyCeWlMwjSm5kzftzjuiSERuH7ZG1wf2hUo"
        full_uri = url+"key="+key+"&q="+query+"&target="+language
        print(full_uri)
        response = requests.post(full_uri)
        response = response.text.replace("\n","")
        #x = x.replace(” “,”“)
        text = dict(json.loads(response))
        text = text["data"]["translations"][0]["translatedText"]
        return text
    
translator = Translator()

# %%
danone = pd.read_csv('data/danone.xlsx - export.csv')
danone
# Out:
#      Employability ratio  List of local jobs  \
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# 5                    NaN                 NaN
# 6                    NaN                 NaN
# 7                    NaN                 NaN
# 8                    NaN                 NaN
# 9                    NaN                 NaN
# 10                   NaN                 NaN
# 11                   NaN                 NaN
# 12                   NaN                 NaN
# 13                   NaN                 NaN
# 14                   NaN                 NaN
# 15                   NaN                 NaN
# 16                   NaN                 NaN
# 17                   NaN                 NaN
# 18                   NaN                 NaN
# 19                   NaN                 NaN
# ...

# %%
emsi = pd.read_excel('data/EMSI_ENGLISH_FRENCH.xlsx')
emsi
# Out:
#       Unnamed: 0                                               jobs  \
# 0              0                                         Abstractor
# 1              1                                   Title Abstractor
# 2              2                          Substance Abuse Clinician
# 3              3                          Substance Abuse Therapist
# 4              4                            Substance Abuse Manager
# 5              5                    TEAP Substance Abuse Specialist
# 6              6          Applied Behavior Analysis (ABA) Therapist
# 7              7           Substance Abuse Counselor (SA Counselor)
# 8              8  Advanced Business Application Programming (ABA...
# 9              9                                        Accompanist
# 10            10                                Academic Researcher
# 11            11                               Academic Coordinator
# 12            12                                   Academic Advisor
# ...

# %%
def get_emsi_fr(job):
    try:
        return emsi[emsi['jobs'].str.startswith(job)]['french_titles'].values[0]
    except:
        pass

get_emsi_fr('Substance Abuse Clinician')
# Out:
# 'Clinicien en toxicomanie'

# %%
def get_emsi_fr_skills(job_fr):
    try:
        return ast.literal_eval(emsi[emsi['french_titles'].str.startswith(job_fr)]['skills'].values[0])
    except:
        pass
    
get_emsi_fr_skills('Clinicien en toxicomanie')
# Out:
# ['Substance Abuse',
#  'Mental Health',
#  'Psychotherapy',
#  'Crisis Intervention',
#  'Case Management',
#  'Social Work',
#  'Mental Health Counseling',
#  'Psychology',
#  'Family Therapy',
#  'Cognitive Behavioral Therapy',
#  'Behavioral Health',
#  'Motivational Interviewing',
#  'Teaching',
#  'eClinicalWorks EMR (ECW)',
#  'Dual Diagnosis',
#  'Psychiatry',
#  'Anger Management',
#  'Substance Dependence',
#  'Software Development Life Cycle',
#  'Treatment Planning',
#  'Dialectical Behavior Therapy',
#  'Trauma',
#  'Clinical Research',
#  'Substance Abuse Counseling',
#  'Mental Diseases',
#  'Event Planning',
#  'Clinical Supervision',
#  'Cardiopulmonary Resuscitation (CPR)',
#  'Fundraising',
#  'Stress Management',
#  'Psychosocial Assessments',
#  'Human Services',
#  'Probation',
#  'Advocacy',
#  'First Aid',
#  'Radiation Treatment Planning',
#  'Play Therapy',
#  'Complex Problem Solving',
#  'Community Mental Health Services',
# ...

# %%
def unique(list1): 
  
    # intilize a null list 
    unique_list = [] 
      
    # traverse for all elements 
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x) 
    # print list 
    for x in unique_list: 
        return x

# %%
danone['Nom du rôle'] = [job.lower() for job in danone['Nom du rôle']]

# %%
jobs = danone['Nom du rôle'].unique()
jobs
# Out:
# array(['adjointe rh', 'alternant technicien de maintenance process',
#        'alternante controle de gestion des flux', 'animateur securite',
#        'animatrice qualite', 'apprenti', 'apprentie laboratoire',
#        'apprentie securite', 'aprrentie production',
#        'assistante de gestion', 'conducteur d installation fruits',
#        'conducteur d installation process', 'conducteur de ligne',
#        'conducteur de palettiseur centralise', 'conductrice de ligne',
#        'conductrice de palettiseur centralise', 'coordinateur',
#        'coordinateur technique', 'gestionnaire matieres premieres',
#        'gestionnaire rh', 'infirmiere', 'ingenieur etudes',
#        'laborantin 1', 'laborantin 2', 'laborantine 2', 'leader',
#        'magasinier pieces detachees', 'manager en ressources humaines',
#        'manager optimisation produit', 'operateur cariste',
#        'operateur cariste magasinier', 'operateur de tri selectif',
# ...

# %%
translator.get_translation('Responsable restaurant', language="en")
# Out:
# https://translation.googleapis.com/language/translate/v2?key=AIzaSyCeWlMwjSm5kzftzjuiSERuH7ZG1wf2hUo&q=Responsable restaurant&target=en
# 'Restaurant manager'

# %%
match_results = matcher.get_top_similarities_en(translator.get_translation('Responsable restaurant', language="en"), emsi.jobs, 5)
match_results
# Out:
#   0%|                                                           | 0/3659 [00:00<?, ?it/s]
# https://translation.googleapis.com/language/translate/v2?key=AIzaSyCeWlMwjSm5kzftzjuiSERuH7ZG1wf2hUo&q=Responsable restaurant&target=en
# 100%|███████████████████████████████████████████████| 3659/3659 [00:17<00:00, 212.71it/s]
# [('Bar Manager', 0.9999999821186419),
#  ('Ranch Foreman', 0.9568964171812391),
#  ('Taxi Driver', 0.9331861170576745),
#  ('Ranch Hand', 0.9096543385925336),
#  ('Restaurant Hostess', 0.8752219056705001)]

# %%
match_results[0][0], match_results[1][0]
# Out:
# ('Bar Manager', 'Ranch Foreman')

# %%
match_results[2][0], get_emsi_fr(match_results[2][0])
# Out:
# ('Taxi Driver', 'Conducteur de taxi')

# %%
results = []
for job in jobs:
    match_results = matcher.get_top_similarities_en(translator.get_translation(job, language="en"), emsi.jobs, 5)
    results.append(
        {
            'job': job, 
            'match_1': get_emsi_fr(match_results[0][0]),
            'match_2': get_emsi_fr(match_results[1][0]),
            'match_3': get_emsi_fr(match_results[2][0]),
            'match_4': get_emsi_fr(match_results[3][0]),
            'match_5': get_emsi_fr(match_results[4][0]),
        }
        
    )
        
df = pd.DataFrame(results)
df
# Out:
#   0%|                                                           | 0/3659 [00:00<?, ?it/s]
# https://translation.googleapis.com/language/translate/v2?key=AIzaSyCeWlMwjSm5kzftzjuiSERuH7ZG1wf2hUo&q=adjointe rh&target=en
# 100%|███████████████████████████████████████████████| 3659/3659 [00:17<00:00, 210.57it/s]
# https://translation.googleapis.com/language/translate/v2?key=AIzaSyCeWlMwjSm5kzftzjuiSERuH7ZG1wf2hUo&q=alternant technicien de maintenance process&target=en
# ...
#   0%|                                                           | 0/3659 [00:00<?, ?it/s]
# https://translation.googleapis.com/language/translate/v2?key=AIzaSyCeWlMwjSm5kzftzjuiSERuH7ZG1wf2hUo&q=alternante controle de gestion des flux&target=en
# ...
#   0%|                                                           | 0/3659 [00:00<?, ?it/s]
# https://translation.googleapis.com/language/translate/v2?key=AIzaSyCeWlMwjSm5kzftzjuiSERuH7ZG1wf2hUo&q=animateur securite&target=en
# ...

# %%
df.to_clipboard()

# %%
job_matches = pd.read_csv('data/Job Match - test.csv')
job_matches
# Out:
#                                             job  \
# 0                                   adjointe rh
# 1   alternant technicien de maintenance process
# 2       alternante controle de gestion des flux
# 3                            animateur securite
# 4                            animatrice qualite
# 5                                      apprenti
# 6                         apprentie laboratoire
# 7                            apprentie securite
# 8                          aprrentie production
# 9                         assistante de gestion
# 10             conducteur d installation fruits
# 11            conducteur d installation process
# 12                          conducteur de ligne
# 13         conducteur de palettiseur centralise
# 14                         conductrice de ligne
# 15        conductrice de palettiseur centralise
# 16                                 coordinateur
# 17                       coordinateur technique
# ...

# %%
job_matches['BEST_MATCH'][1]
# Out:
# 'Technicien de systemes (installation, maintenance et reparation)'

# %%
job_skills_list = [['a', 'b', 'c', 'd'], ['a', 'b', 'c', 'e'], ['a', 'b', 'x', 'y'], ['a', 'v', 'j', 'p']]

user_skills = ['a', 'b', 'c', 'd']

for job_skills in zip(emsi['skills'], emsi['french_titles']):
    count = 0
    for skill in user_skills:
        if skill in job_skills:
            count = count + 1
    
    print('Match score: ', str(count/5))
# Out:
# Match score:  0.8
# Match score:  0.6
# Match score:  0.4
# Match score:  0.2

# %%
skill_list_1 = get_emsi_fr_skills('Ingenieur Services Web')
skill_list_1
# Out:
# ['Web Services',
#  'HyperText Markup Language (HTML)',
#  'JavaScript (Programming Language)',
#  'SQL (Programming Language)',
#  'Java (Programming Language)',
#  'Linux',
#  'Web Development',
#  'Cascading Style Sheets (CSS)',
#  'Troubleshooting (Problem Solving)',
#  'Amazon Web Services',
#  'Software Development',
#  'Cloud Computing',
#  'Complex Problem Solving',
#  'Software Engineering',
#  'Technical Support',
#  'Project Management',
#  'PHP (Scripting Language)',
#  'MySQL',
#  'C++ (Programming Language)',
#  'Web Design',
#  'Extensible Markup Language (XML)',
#  'C (Programming Language)',
#  'Operating Systems',
#  'Unix',
#  'Agile Software Development',
#  'Microsoft SQL Servers',
#  'Team Leadership',
#  'Telecommunications',
#  'Python (Programming Language)',
#  'Windows Servers',
#  'JQuery',
#  'Systems Engineering',
#  'C# (Programming Language)',
#  'Active Directory',
#  'Search Engine Optimization',
#  'Systems Management',
#  'Program Management',
# ...

# %%
skill_list_2 = get_emsi_fr_skills('Developpeur HTML')
skill_list_2
# Out:
# ['Cascading Style Sheets (CSS)',
#  'HyperText Markup Language (HTML)',
#  'JavaScript (Programming Language)',
#  'Web Development',
#  'PHP (Scripting Language)',
#  'Adobe Photoshop',
#  'JQuery',
#  'Web Design',
#  'SQL (Programming Language)',
#  'WordPress',
#  'MySQL',
#  'Java (Programming Language)',
#  'HTML5',
#  'Front End (Software Engineering)',
#  'Software Engineering',
#  'Adobe Illustrator',
#  'Search Engine Optimization',
#  'Extensible Markup Language (XML)',
#  'Graphic Design',
#  'Adobe Dreamweaver',
#  'Social Media',
#  'C (Programming Language)',
#  'C++ (Programming Language)',
#  'Python (Programming Language)',
#  'Bootstrap (Front-End Framework)',
#  'Adobe Creative Suite',
#  'User Interface',
#  'Software Development',
#  'Troubleshooting (Problem Solving)',
#  'C# (Programming Language)',
#  'Linux',
#  'Microsoft SQL Servers',
#  'Adobe Flash',
#  'User Experience',
#  'Web Applications',
#  'Project Management',
#  'Adobe InDesign',
# ...

# %%
count = 0
for skill_2 in skill_list_2:
    if skill_2 in skill_list_1[:10]:
        count = count + 1

if count > 2:
    print(count)
# Out:
# 8

# %%
def get_similarity(job_fr):
    
    results = {}
    
    for emsi_job in emsi['french_titles']:
        emsi_job_skills = get_emsi_fr_skills(emsi_job)
        count = 0
        for skill in get_emsi_fr_skills(job_fr):
            if skill in emsi_job_skills:
                count = count + 1
        if count > 10:    
            results[emsi_job] = count
            
    return results

get_similarity('Developpeur HTML')
# Out:
# {'Developpeur Advanced Business Application Programming (ABAP)': 12,
#  'Responsable analytique (informatique et mathematiques)': 12,
#  'Analyste en modelisation (informatique et mathematiques)': 11,
#  'Analyste statistique (informatique et mathematiques)': 18,
#  'Analyste de contenu (informatique et mathematiques)': 21,
#  'Analyste de l information (informatique et mathematiques)': 12,
#  'Analyste en optimisation (informatique et mathematiques)': 14,
#  'Analyste de contenu (operations commerciales et financieres)': 17,
#  'Administrateur d application': 13,
#  'Architecte d application': 19,
#  'Ingenieur d applications': 14,
#  'Programmeur d applications': 22,
#  'Consultant d application': 15,
#  'Developpeur d applications': 25,
#  'Scientifique des applications': 16,
#  'Architecte': 19,
#  'Architecte SOA (Service-Oriented Architecture)': 17,
#  'Architecte Java': 18,
#  'Architecte SharePoint': 17,
#  'Architecte .Net': 24,
#  'Architecte Web': 28,
# ...

# %%
get_similarity('Technicien de systemes (installation, maintenance et reparation)')
# Out:
# 9 Analyste de suivi (informatique et mathematiques)
# 9 Analyste des operations (informatique et mathematiques)
# 9 Administrateur d applications
# 9 Gestionnaire de deploiement
# 9 Ingenieur Support (Architecture et Ingenierie)
# 9 Ingenieur Operations (Architecture et Ingenierie)
# 10 Expert en matiere informatique
# 9 Ingenieur sur le terrain (installation, maintenance et reparation)
# 9 Aide aux metiers
# 9 Ingenieur en gestion des identites
# 9 Technicien d infrastructure
# 9 Administrateur reseau informatique
# 9 Ingenieur terrain IT
# 9 Specialiste du service d assistance informatique
# 9 Ingenieur support informatique
# 10 Specialiste du support informatique
# 9 Administrateur du support informatique
# 9 Administrateur systeme informatique
# 10 Administrateur principal
# 9 Technicien reseau
# 9 Administrateur de reseau local (LAN)
# 9 Ingenieur CNO
# 9 Technicien PC
# 9 Chef de section
# 9 Administrateur de serveur
# 10 Specialiste en technologie
# ...

# %%
similarities = get_similarity('Technicien de systemes (installation, maintenance et reparation)')
similarities
# Out:
# {'Analyste de suivi (informatique et mathematiques)': 9,
#  'Analyste des operations (informatique et mathematiques)': 9,
#  'Administrateur d applications': 9,
#  'Gestionnaire de deploiement': 9,
#  'Ingenieur Support (Architecture et Ingenierie)': 9,
#  'Ingenieur Operations (Architecture et Ingenierie)': 9,
#  'Expert en matiere informatique': 10,
#  'Ingenieur sur le terrain (installation, maintenance et reparation)': 9,
#  'Aide aux metiers': 9,
#  'Ingenieur en gestion des identites': 9,
#  'Technicien d infrastructure': 9,
#  'Administrateur reseau informatique': 9,
#  'Ingenieur terrain IT': 9,
#  'Specialiste du service d assistance informatique': 9,
#  'Ingenieur support informatique': 9,
#  'Specialiste du support informatique': 10,
#  'Administrateur du support informatique': 9,
#  'Administrateur systeme informatique': 9,
#  'Administrateur principal': 10,
#  'Technicien reseau': 9,
#  'Administrateur de reseau local (LAN)': 9,
#  'Ingenieur CNO': 9,
# ...

# %%
for similarity in similarities:
    print(similarity, similarities[similarity])
# Out:
# Analyste de suivi (informatique et mathematiques) 9
# Analyste des operations (informatique et mathematiques) 9
# Administrateur d applications 9
# Gestionnaire de deploiement 9
# Ingenieur Support (Architecture et Ingenierie) 9
# Ingenieur Operations (Architecture et Ingenierie) 9
# Expert en matiere informatique 10
# Ingenieur sur le terrain (installation, maintenance et reparation) 9
# Aide aux metiers 9
# Ingenieur en gestion des identites 9
# Technicien d infrastructure 9
# Administrateur reseau informatique 9
# Ingenieur terrain IT 9
# Specialiste du service d assistance informatique 9
# Ingenieur support informatique 9
# Specialiste du support informatique 10
# Administrateur du support informatique 9
# Administrateur systeme informatique 9
# Administrateur principal 10
# Technicien reseau 9
# Administrateur de reseau local (LAN) 9
# Ingenieur CNO 9
# Technicien PC 9
# Chef de section 9
# Administrateur de serveur 9
# Specialiste en technologie 10
# ...

# %%
def get_similarity(job_fr):
    #print(skills)
    for job_skills, job in zip(emsi['skills'], emsi['french_titles']):
        #print(job_skills)
        count = 0
        for skill in user_skills:
            if skill in job_skills[:10]:
                count = count + 1
        
        if count > 2:
            print(job, count/10)       

        #print(str(count/len(user_skills)), job)

get_similarity(skill_list_)
# Out:
# Clinicien en toxicomanie 0.3
# Gestionnaire de toxicomanie 0.3
# Specialiste TEAP de la toxicomanie 0.3
# Conseiller en toxicomanie (conseiller SA) 0.3
# Developpeur Advanced Business Application Programming (ABAP) 0.3
# Coordonnateur d acces 0.3
# Agent administratif 0.3
# Administrateur de l entreprise 0.3
# Concepteur de vetements 0.3
# Acheteur adjoint 0.3
# Defenseur de la marque 0.3
# Technicien haut debit 0.3
# Infirmiere de laboratoire de catheterisme cardiaque 0.3
# Specialiste de carriere 0.3
# Echo Cardiographer 0.3
# Gestionnaire de club 0.3
# Gestionnaire de codage (informatique et mathematiques) 0.3
# Analyste en codage 0.3
# Coordonnateur judiciaire 0.3
# Tree Crew 0.3
# Chef d equipe agricole 0.3
# Coupe-arbre 0.3
# Assistant client 0.3
# Associe, service a la clientele (ventes et connexes) 0.3
# Directeur de laboratoire 0.3
# Medecin 0.3
# Driver Merchandiser 0.3
# Conducteur a plat 0.3
# Responsable de l execution des marchandises (gestion) 0.3
# ...

# %%
for job in job_matches['job']:
    get_similarity(get_emsi_fr_skills(job))
# Out:
# Clinicien en toxicomanie 0.3
# Gestionnaire de toxicomanie 0.3
# Specialiste TEAP de la toxicomanie 0.3
# Conseiller en toxicomanie (conseiller SA) 0.3
# Developpeur Advanced Business Application Programming (ABAP) 0.3
# Coordonnateur d acces 0.3
# Agent administratif 0.3
# Administrateur de l entreprise 0.3
# Concepteur de vetements 0.3
# Acheteur adjoint 0.3
# Defenseur de la marque 0.3
# Technicien haut debit 0.3
# Infirmiere de laboratoire de catheterisme cardiaque 0.3
# Specialiste de carriere 0.3
# Echo Cardiographer 0.3
# Gestionnaire de club 0.3
# Gestionnaire de codage (informatique et mathematiques) 0.3
# Analyste en codage 0.3
# Coordonnateur judiciaire 0.3
# Tree Crew 0.3
# Chef d equipe agricole 0.3
# Coupe-arbre 0.3
# Assistant client 0.3
# Associe, service a la clientele (ventes et connexes) 0.3
# Directeur de laboratoire 0.3
# Medecin 0.3
# Driver Merchandiser 0.3
# Conducteur a plat 0.3
# Responsable de l execution des marchandises (gestion) 0.3
# ...

# %%
similarity_result = []

for job in job_matches['BEST_MATCH']:
    
    similarities = get_similarity(job)
    
    for similarity in similarities:
    
        similarity_result.append(
            {
                'jobs': job,
                'similar_job': similarity,
                'ratio': similarities[similarity],
                'jobs_skills': get_emsi_fr_skills(job),
                'similar_job_skills': get_emsi_fr_skills(similarity)
            }
        )
 
similarity_result
# Out:
# [{'jobs': 'Assistant enfant',
#   'similar_job': 'Analyste administratif',
#   'ratio': 9,
#   'jobs_skills': ['Animal Husbandry',
#    'Welfare',
#    'Data Entry',
#    'Teamwork',
#    'Teaching',
#    'Filing',
#    'Merchandising',
#    'Event Planning',
#    'Cardiopulmonary Resuscitation (CPR)',
#    'Horse Care',
#    'First Aid',
#    'Complex Problem Solving',
#    'Billing',
#    'Child Safeguarding',
#    'Animal Handling',
#    'Accounting',
#    'Detail Oriented',
#    'Cashiering',
#    'Office Management',
#    'Customer Satisfaction',
#    'Veterinary Medicine',
#    'Spanish Language',
#    'Office Assistant',
#    'Team Building',
#    'Typing',
#    'Multitasking',
#    'Customer Relationship Management',
#    'Horse Training',
#    'Restaurant Operation',
#    'Telephone Skills',
#    'Safe Restraining Techniques (Veterinary)',
#    'Inventory Management',
#    'Adobe Photoshop',
#    'Classification And Regression Tree (CART)',
#    'Accounts Payable',
# ...
